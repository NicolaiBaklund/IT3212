# %%
from data import feeder

# %%
for feed in ["A1", "A2"]:
    temp = feeder(feed)
    temp.plot()
# Out:
# Plotted data statistics for Feeder A1:
#   Date range: 2017-01-01 00:00 to 2020-12-31 23:00
#   Total records: 35,040
#   Non-null records: 33,832
#   Missing records: 1,208
#   Mean consumption: 69.67
#   Min consumption: 1.00
#   Max consumption: 178.00
# Plotted data statistics for Feeder A2:
#   Date range: 2017-01-01 00:00 to 2020-12-31 23:00
#   Total records: 35,040
#   Non-null records: 34,478
#   Missing records: 562
#   Mean consumption: 56.71
#   Min consumption: 4.00
#   Max consumption: 825.00
