# %% [markdown]
# ## Exploringh B2 as an example

# %% [markdown]
# ![image.png](attachment:image.png)
#
# As we see here, B2 is one of the highest consumers but still has low correlation to other feeders.
#
# We see that it's one of the least correlated to the total consumption, and also one of the least correlated to other feeders.
#
# ![image-2.png](attachment:image-2.png)

# %%
from data import feeder, substations

# %%
B2_data = feeder('B2')
B2_data.plot() #Look at the graph
# Out:
# Plotted data statistics for Feeder B2:
#   Date range: 2017-01-01 00:00 to 2020-12-31 23:00
#   Total records: 34,944
#   Non-null records: 34,094
#   Missing records: 850
#   Mean consumption: 128.89
#   Min consumption: 1.00
#   Max consumption: 999.00

# %% [markdown]
# ## Apply IQR to B2

# %%
B2_data.apply_iqr()
B2_data.plot() #Look at the graph after applying IQR
# Out:
# ...
# IQR OUTLIER DETECTION AND HANDLING - FEEDER B2
# ...
# Window size: 720 hours (30.0 days)
# IQR multiplier: 1.5
# Outlier action: CAP
# Minimum periods: 360
#
# Calculating rolling IQR statistics...
# Total non-null records: 34,094
# Outliers detected: 95 (0.28%)
#
# Capping outliers to boundary values...
# Capped 95 outlier values
#
# ...
# BEFORE AND AFTER COMPARISON
# ...
#
# Original data statistics:
#   Count: 34,094
#   Mean: 128.89
#   Std: 61.00
#   Min: 1.00
#   Max: 999.00
#
# Processed data statistics:
#   Count: 34,094
#   Mean: 128.80
#   Std: 60.61
#   Min: 2.00
#   Max: 350.00
#
# Example outlier adjustments (first 5):
#   2017-01-06 08:00 | Original: 57.00 → Processed: 65.00 | Bounds: [65.00, 321.00] | LOW outlier
#   2017-02-03 17:00 | Original: 302.00 → Processed: 296.50 | Bounds: [60.50, 296.50] | HIGH outlier
#   2017-02-04 17:00 | Original: 300.00 → Processed: 297.00 | Bounds: [57.00, 297.00] | HIGH outlier
# ...

# %%
B2_data.plot(start_date='2018-04-01', end_date='2019-02-01') #Look at the graph
# Out:
# Plotted data statistics for Feeder B2:
#   Date range: 2018-04-01 00:00 to 2019-02-01 00:00
#   Total records: 7,249
#   Non-null records: 7,072
#   Missing records: 177
#   Mean consumption: 148.34
#   Min consumption: 14.00
#   Max consumption: 350.00
