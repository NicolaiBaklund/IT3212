# %%
from data import feeder, substations

# %%
feeder_name = 'L3'

# %% [markdown]
# ## Apply Z-score Outlier Removal

# %%
# Create a feeder instance
feeder_a1 = feeder(feeder_name)
feeder_a1.plot()
# Apply Z-score outlier removal with default settings
result = feeder_a1.apply_zscore()

# Apply with custom parameters
result = feeder_a1.apply_zscore(
    iterations=3,
    window_hours_list=[30*24, 14*24, 7*24],  # 30, 14, 7 days
    thresholds=[2.7, 2.7, 2.7],
    quantile=0.75
)

# Visualize the results
feeder_a1.plot()
# Out:
# Plotted data statistics for Feeder L3:
#   Date range: 2017-01-01 00:00 to 2020-12-31 23:00
#   Total records: 35,016
#   Non-null records: 34,211
#   Missing records: 805
#   Mean consumption: 47.24
#   Min consumption: 2.00
#   Max consumption: 216.00
#
# 🔍 APPLYING Z-SCORE OUTLIER DETECTION TO FEEDER L3
# ======================================================================
# Initial data shape: (35016, 2)
# Iterations: 3
# Window sizes (hours): [720, 336, 168]
# Thresholds: [2.75, 2.7, 2.7]
# Capping quantile: 75th percentile
#
# --- Iteration 1 ---
# Window: 720 hours (30.0 days)
# Threshold: 2.75
# Outliers detected: 164 (0.47%)
# Capping value (75th percentile): 61.00
# Mean change: 47.24 → 47.46
# Std change: 19.98 → 19.80
#
# --- Iteration 2 ---
# Window: 336 hours (14.0 days)
# Threshold: 2.7
# Outliers detected: 201 (0.57%)
# Capping value (75th percentile): 61.00
# Mean change: 47.46 → 47.73
# Std change: 19.80 → 19.65
#
# --- Iteration 3 ---
# Window: 168 hours (7.0 days)
# Threshold: 2.7
# Outliers detected: 149 (0.43%)
# Capping value (75th percentile): 61.00
# Mean change: 47.73 → 47.93
# Std change: 19.65 → 19.53
#
# ==================================================
# FINAL SUMMARY - FEEDER L3
# ==================================================
# Total iterations: 3
# Total outliers across all iterations: 514
# Final consumption column: consumption_capped_3
# Original mean: 47.24
# Final mean: 47.93
# Original std: 19.98
# Final std: 19.53
# ✅ Updated feeder consumption data with final processed values
#
# 🔍 APPLYING Z-SCORE OUTLIER DETECTION TO FEEDER L3
# ======================================================================
# Initial data shape: (35016, 2)
# Iterations: 3
# Window sizes (hours): [720, 336, 168]
# Thresholds: [2.7, 2.7, 2.7]
# Capping quantile: 75th percentile
#
# --- Iteration 1 ---
# Window: 720 hours (30.0 days)
# Threshold: 2.7
# Outliers detected: 129 (0.37%)
# Capping value (75th percentile): 61.00
# Mean change: 47.93 → 48.11
# Std change: 19.53 → 19.41
#
# --- Iteration 2 ---
# Window: 336 hours (14.0 days)
# Threshold: 2.7
# Outliers detected: 169 (0.48%)
# Capping value (75th percentile): 61.00
# Mean change: 48.11 → 48.33
# Std change: 19.41 → 19.29
#
# --- Iteration 3 ---
# Window: 168 hours (7.0 days)
# Threshold: 2.7
# Outliers detected: 125 (0.36%)
# Capping value (75th percentile): 61.00
# Mean change: 48.33 → 48.49
# Std change: 19.29 → 19.19
#
# ==================================================
# FINAL SUMMARY - FEEDER L3
# ==================================================
# Total iterations: 3
# Total outliers across all iterations: 423
# Final consumption column: consumption_capped_3
# Original mean: 47.93
# Final mean: 48.49
# Original std: 19.53
# Final std: 19.19
# ✅ Updated feeder consumption data with final processed values
# Plotted data statistics for Feeder L3:
#   Date range: 2017-01-01 00:00 to 2020-12-31 23:00
#   Total records: 35,016
#   Non-null records: 34,211
#   Missing records: 805
#   Mean consumption: 48.49
#   Min consumption: 3.00
#   Max consumption: 94.00
